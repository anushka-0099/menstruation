# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r'FedCycleData071012 (2).csv')

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
data.isnull().sum()
# Out:
# ClientID                0
# CycleNumber             0
# Group                   0
# CycleWithPeakorNot      0
# ReproductiveCategory    0
#                        ..
# NextpregM               0
# Spousesame              0
# SpousesameM             0
# Timeattemptpreg         0
# BMI                     0
# Length: 80, dtype: int64

# %%
data['Group'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.columns
# Out:
# Index(['ClientID', 'CycleNumber', 'Group', 'CycleWithPeakorNot',
#        'ReproductiveCategory', 'LengthofCycle', 'MeanCycleLength',
#        'EstimatedDayofOvulation', 'LengthofLutealPhase', 'FirstDayofHigh',
#        'TotalNumberofHighDays', 'TotalHighPostPeak', 'TotalNumberofPeakDays',
#        'TotalDaysofFertility', 'TotalFertilityFormula', 'LengthofMenses',
#        'MeanMensesLength', 'MensesScoreDayOne', 'MensesScoreDayTwo',
#        'MensesScoreDayThree', 'MensesScoreDayFour', 'MensesScoreDayFive',
#        'MensesScoreDaySix', 'MensesScoreDaySeven', 'MensesScoreDayEight',
#        'MensesScoreDayNine', 'MensesScoreDayTen', 'MensesScoreDay11',
#        'MensesScoreDay12', 'MensesScoreDay13', 'MensesScoreDay14',
#        'MensesScoreDay15', 'TotalMensesScore', 'MeanBleedingIntensity',
#        'NumberofDaysofIntercourse', 'IntercourseInFertileWindow',
#        'UnusualBleeding', 'PhasesBleeding', 'IntercourseDuringUnusBleed',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1665 entries, 0 to 1664
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ClientID                    1665 non-null   object
#  1   CycleNumber                 1665 non-null   int64
#  2   Group                       1665 non-null   int64
#  3   CycleWithPeakorNot          1665 non-null   int64
#  4   ReproductiveCategory        1665 non-null   int64
#  5   LengthofCycle               1665 non-null   int64
#  6   MeanCycleLength             1665 non-null   object
#  7   EstimatedDayofOvulation     1665 non-null   object
#  8   LengthofLutealPhase         1665 non-null   object
#  9   FirstDayofHigh              1665 non-null   object
#  10  TotalNumberofHighDays       1665 non-null   object
#  11  TotalHighPostPeak           1665 non-null   object
#  12  TotalNumberofPeakDays       1665 non-null   object
# ...

# %%
data.describe()
# Out:
#        CycleNumber        Group  CycleWithPeakorNot  ReproductiveCategory  \
# count  1665.000000  1665.000000         1665.000000           1665.000000
# mean      8.040841     0.382583            0.912312              0.055255
# std       6.593686     0.486164            0.282925              0.479706
# min       1.000000     0.000000            0.000000              0.000000
# 25%       3.000000     0.000000            1.000000              0.000000
# 50%       7.000000     0.000000            1.000000              0.000000
# 75%      11.000000     1.000000            1.000000              0.000000
# max      45.000000     1.000000            1.000000              9.000000
#
#        LengthofCycle
# count    1665.000000
# mean       29.299099
# std         3.887932
# min        18.000000
# 25%        27.000000
# 50%        29.000000
# 75%        31.000000
# max        54.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

# %%
sns.distplot(data['CycleNumber'],bins=15)
# Out:
# C:\Users\Anushka\AppData\Local\Temp\ipykernel_12272\2551089591.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['CycleNumber'],bins=15)
# <Axes: xlabel='CycleNumber', ylabel='Density'>

# %%
sns.distplot(data['LengthofCycle'],bins=15)
# Out:
# C:\Users\Anushka\AppData\Local\Temp\ipykernel_12272\1051399277.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['LengthofCycle'],bins=15)
# <Axes: xlabel='LengthofCycle', ylabel='Density'>

# %%
sns.boxplot(data['CycleNumber'])
# Out:
# <Axes: ylabel='CycleNumber'>

# %%
outlier_len_cycle=data.loc[(data['LengthofCycle']>20)]

# %%
outlier_len_cycle
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0     nfp8122            1      0                   1                     0
# 1     nfp8122            2      0                   1                     0
# 2     nfp8122            3      0                   1                     0
# 3     nfp8122            4      0                   1                     0
# 4     nfp8122            5      0                   1                     0
# ...       ...          ...    ...                 ...                   ...
# 1660  nfp8334            7      1                   1                     0
# 1661  nfp8334            8      1                   1                     0
# 1662  nfp8334            9      1                   1                     0
# 1663  nfp8334           10      1                   1                     1
# 1664  nfp8334           11      1                   1                     2
#
# ...

# %%
sns.boxplot(data['CycleNumber'])
# Out:
# <Axes: ylabel='CycleNumber'>

# %%
cycle_Number_out=data.loc[(data['CycleNumber']>25)]

# %%
cycle_Number_out
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 25    nfp8122           26      0                   1                     0
# 26    nfp8122           27      0                   1                     0
# 27    nfp8122           28      0                   1                     0
# 28    nfp8122           29      0                   1                     0
# 29    nfp8122           30      0                   1                     0
# 30    nfp8122           31      0                   1                     0
# 31    nfp8122           32      0                   1                     0
# 32    nfp8122           33      0                   1                     0
# 33    nfp8122           34      0                   1                     0
# 34    nfp8122           35      0                   1                     0
# 35    nfp8122           36      0                   0                     0
# ...

# %%
data=data.replace(' ',np.nan)

# %%
missing_values=data.isnull().sum()

# %%
num_columns_with_missing = (missing_values > 0).sum()

# %%
num_columns_with_missing
# Out:
# 74

# %%
total_rows = len(data)

columns_with_missing = missing_values[missing_values > (total_rows / 2)]

# Plot the results
plt.figure(figsize=(10, 6))
columns_with_missing.plot(kind='bar', color='blue', alpha=0.8)
plt.title('Columns with More Than Half Missing Values')
plt.ylabel('Number of Missing Values')
plt.xlabel('Columns')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
columns_to_remove = missing_values[missing_values > (total_rows / 2)].index

cleaned_data = data.drop(columns=columns_to_remove)

# %%
cleaned_data.to_csv('cleaned_menstruation_data.csv',index=False)

# %%
df=pd.read_csv('cleaned_menstruation_data.csv')

# %%
df.head()
# Out:
#   ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0  nfp8122            1      0                   1                     0
# 1  nfp8122            2      0                   1                     0
# 2  nfp8122            3      0                   1                     0
# 3  nfp8122            4      0                   1                     0
# 4  nfp8122            5      0                   1                     0
#
#    LengthofCycle  EstimatedDayofOvulation  LengthofLutealPhase  \
# 0             29                     17.0                 12.0
# 1             27                     15.0                 12.0
# 2             29                     15.0                 14.0
# 3             27                     15.0                 12.0
# 4             28                     16.0                 12.0
#
#    FirstDayofHigh  TotalNumberofHighDays  ...  LengthofMenses  \
# 0            12.0                    5.0  ...             5.0
# ...

# %%
df=df.drop(columns='ClientID')

# %%
df.isnull().sum()
# Out:
# CycleNumber                     0
# Group                           0
# CycleWithPeakorNot              0
# ReproductiveCategory            0
# LengthofCycle                   0
# EstimatedDayofOvulation       150
# LengthofLutealPhase           151
# FirstDayofHigh                258
# TotalNumberofHighDays          12
# TotalHighPostPeak               3
# TotalNumberofPeakDays          16
# TotalDaysofFertility           31
# TotalFertilityFormula           2
# LengthofMenses                  4
# MensesScoreDayOne               4
# MensesScoreDayTwo               4
# MensesScoreDayThree            25
# MensesScoreDayFour             87
# MensesScoreDayFive            434
# TotalMensesScore                4
# NumberofDaysofIntercourse       1
# IntercourseInFertileWindow      1
# UnusualBleeding                20
# dtype: int64

# %%
df
# Out:
#       CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0               1      0                   1                     0
# 1               2      0                   1                     0
# 2               3      0                   1                     0
# 3               4      0                   1                     0
# 4               5      0                   1                     0
# ...           ...    ...                 ...                   ...
# 1660            7      1                   1                     0
# 1661            8      1                   1                     0
# 1662            9      1                   1                     0
# 1663           10      1                   1                     1
# 1664           11      1                   1                     2
#
#       LengthofCycle  EstimatedDayofOvulation  LengthofLutealPhase  \
# 0                29                     17.0                 12.0
# ...

# %%
df.dtypes
# Out:
# CycleNumber                     int64
# Group                           int64
# CycleWithPeakorNot              int64
# ReproductiveCategory            int64
# LengthofCycle                   int64
# EstimatedDayofOvulation       float64
# LengthofLutealPhase           float64
# FirstDayofHigh                float64
# TotalNumberofHighDays         float64
# TotalHighPostPeak             float64
# TotalNumberofPeakDays         float64
# TotalDaysofFertility          float64
# TotalFertilityFormula         float64
# LengthofMenses                float64
# MensesScoreDayOne             float64
# MensesScoreDayTwo             float64
# MensesScoreDayThree           float64
# MensesScoreDayFour            float64
# MensesScoreDayFive            float64
# TotalMensesScore              float64
# NumberofDaysofIntercourse     float64
# IntercourseInFertileWindow    float64
# UnusualBleeding               float64
# dtype: object

# %%
for i in df.columns:
    if ( df[i].isnull().sum() ) > 0:
        df[i]= df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# CycleNumber                   0
# Group                         0
# CycleWithPeakorNot            0
# ReproductiveCategory          0
# LengthofCycle                 0
# EstimatedDayofOvulation       0
# LengthofLutealPhase           0
# FirstDayofHigh                0
# TotalNumberofHighDays         0
# TotalHighPostPeak             0
# TotalNumberofPeakDays         0
# TotalDaysofFertility          0
# TotalFertilityFormula         0
# LengthofMenses                0
# MensesScoreDayOne             0
# MensesScoreDayTwo             0
# MensesScoreDayThree           0
# MensesScoreDayFour            0
# MensesScoreDayFive            0
# TotalMensesScore              0
# NumberofDaysofIntercourse     0
# IntercourseInFertileWindow    0
# UnusualBleeding               0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0               1      0                   1                     0
# 1               2      0                   1                     0
# 2               3      0                   1                     0
# 3               4      0                   1                     0
# 4               5      0                   1                     0
# ...           ...    ...                 ...                   ...
# 1660            7      1                   1                     0
# 1661            8      1                   1                     0
# 1662            9      1                   1                     0
# 1663           10      1                   1                     1
# 1664           11      1                   1                     2
#
#       LengthofCycle  EstimatedDayofOvulation  LengthofLutealPhase  \
# 0                29                17.000000            12.000000
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['LengthofMenses'], y=df['LengthofCycle'])
# Out:
# <Axes: xlabel='LengthofMenses', ylabel='LengthofCycle'>

# %%
df.isnull().sum()
# Out:
# CycleNumber                   0
# Group                         0
# CycleWithPeakorNot            0
# ReproductiveCategory          0
# LengthofCycle                 0
# EstimatedDayofOvulation       0
# LengthofLutealPhase           0
# FirstDayofHigh                0
# TotalNumberofHighDays         0
# TotalHighPostPeak             0
# TotalNumberofPeakDays         0
# TotalDaysofFertility          0
# TotalFertilityFormula         0
# LengthofMenses                0
# MensesScoreDayOne             0
# MensesScoreDayTwo             0
# MensesScoreDayThree           0
# MensesScoreDayFour            0
# MensesScoreDayFive            0
# TotalMensesScore              0
# NumberofDaysofIntercourse     0
# IntercourseInFertileWindow    0
# UnusualBleeding               0
# dtype: int64

# %%
df.shape
# Out:
# (1665, 23)

# %%
import matplotlib.pyplot as plt # Import the pyplot module from matplotlib and alias it as plt
import seaborn as sns
df["LengthofMenses"] = df. LengthofMenses
matrix = df.corr()
plt.figure(figsize=(20,14))
# plotting correlation matrix
sns.heatmap(matrix, cmap="Greens", annot=True)
# Out:
# <Axes: >

# %%
outliers_percentages = []

for col in df.columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outliers_count = ((df[col] < lower_bound) | (df[col] > upper_bound)).sum()
    outliers_percentage = (outliers_count / len(df[col])) * 100

    outliers_percentages.append({'Column': col, 'Outlier Percentage': outliers_percentage})

outliers_df = pd.DataFrame(outliers_percentages)
outliers_df = outliers_df.sort_values(by='Outlier Percentage', ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,10))
ax = sns.barplot(data= outliers_df , x="Outlier Percentage", y= "Column" )

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')

plt.show()

# %%
y = df["LengthofCycle"]
X = df.drop('LengthofMenses', axis=1)
X = df.drop('LengthofCycle', axis=1)

# %%
y
# Out:
# 0       29
# 1       27
# 2       29
# 3       27
# 4       28
#         ..
# 1660    29
# 1661    28
# 1662    28
# 1663    40
# 1664    24
# Name: LengthofCycle, Length: 1665, dtype: int64

# %%
X.columns
X.shape
# Out:
# (1665, 22)

# %%
X = X.drop('LengthofMenses', axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
X= scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('Group',axis=1)
X_train, X_test ,y_train, y_test = train_test_split(X,y,train_size=0.8, random_state= 42)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth=5)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error
r2 = r2_score(y_test, y_pred)

# %%
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.0426
# Mean Squared Error (MSE): 0.0344
# Root Mean Squared Error (RMSE): 0.1855
# R² Score: 0.9975

# %%
import pickle
with open("model_tracker_cycle.pkl", "wb") as file:
    pickle.dump(model, file)

# %%
X.columns
X.shape
# Out:
# (1665, 22)

# %%
X.shape
# Out:
# (1665, 22)

# %%
X.columns
# Out:
# Index(['CycleNumber', 'CycleWithPeakorNot', 'ReproductiveCategory',
#        'LengthofCycle', 'EstimatedDayofOvulation', 'LengthofLutealPhase',
#        'FirstDayofHigh', 'TotalNumberofHighDays', 'TotalHighPostPeak',
#        'TotalNumberofPeakDays', 'TotalDaysofFertility',
#        'TotalFertilityFormula', 'LengthofMenses', 'MensesScoreDayOne',
#        'MensesScoreDayTwo', 'MensesScoreDayThree', 'MensesScoreDayFour',
#        'MensesScoreDayFive', 'TotalMensesScore', 'NumberofDaysofIntercourse',
#        'IntercourseInFertileWindow', 'UnusualBleeding'],
#       dtype='object')

# %%
X
# Out:
#       CycleNumber  CycleWithPeakorNot  ReproductiveCategory  LengthofCycle  \
# 0               1                   1                     0             29
# 1               2                   1                     0             27
# 2               3                   1                     0             29
# 3               4                   1                     0             27
# 4               5                   1                     0             28
# ...           ...                 ...                   ...            ...
# 1660            7                   1                     0             29
# 1661            8                   1                     0             28
# 1662            9                   1                     0             28
# 1663           10                   1                     1             40
# 1664           11                   1                     2             24
#
# ...

# %%
import matplotlib.pyplot as plt

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

plt.figure(figsize=(10, 5))

plt.scatter(y_train, y_train_pred, color="blue", label="Train Data", alpha=0.6)
plt.scatter(y_test, y_test_pred, color="red", label="Test Data", alpha=0.6)

plt.plot([min(y), max(y)], [min(y), max(y)], linestyle="--", color="black")
plt.xlabel("Actual Length of Cycle")
plt.ylabel("Predicted Length of Cycle")
plt.title("Actual vs. Predicted Values")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve

train_sizes = np.linspace(0.1, 1.0, 10)

train_sizes, train_scores, test_scores = learning_curve(
    model, X, y, train_sizes=train_sizes, cv=5, scoring="r2", n_jobs=-1
)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 5))
plt.plot(train_sizes, train_mean, 'o-', color="blue", label="Training Score")
plt.plot(train_sizes, test_mean, 'o-', color="red", label="Cross-Validation Score")

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="blue", alpha=0.2)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="red", alpha=0.2)

plt.xlabel("Training Size")
plt.ylabel("R² Score")
plt.title("Learning Curve (Decision Tree Regressor)")
plt.legend()
plt.grid()
plt.show()

# %%
X
# Out:
#       CycleNumber  CycleWithPeakorNot  ReproductiveCategory  LengthofCycle  \
# 0               1                   1                     0             29
# 1               2                   1                     0             27
# 2               3                   1                     0             29
# 3               4                   1                     0             27
# 4               5                   1                     0             28
# ...           ...                 ...                   ...            ...
# 1660            7                   1                     0             29
# 1661            8                   1                     0             28
# 1662            9                   1                     0             28
# 1663           10                   1                     1             40
# 1664           11                   1                     2             24
#
# ...
